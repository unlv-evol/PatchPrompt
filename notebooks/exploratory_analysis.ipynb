# %% [markdown]
# # Exploratory Analysis
#
# This notebook documents the canonical dataset used by the replication package. It verifies the number of cases, inspects derived metadata, and reproduces descriptive summaries used in the paper.

# %% [markdown]
# ## 1. Load the canonical analysis dataset
#
# The package keeps `dataset/processed/final_analysis_dataset.csv` unchanged. Repository, PR number, merged, and closed indicators are derived at runtime from `PR_Link` and `Status`.

# %%
from pathlib import Path
import sys

# Resolve repository root even when Jupyter starts in a different working directory.
ROOT = Path.cwd()
for candidate in [ROOT, *ROOT.parents]:
    if (candidate / "analysis").exists() and (candidate / "dataset").exists():
        ROOT = candidate
        break
sys.path.insert(0, str(ROOT))

import pandas as pd
import numpy as np
from analysis.common import load_analysis_dataset

df = load_analysis_dataset(ROOT)
df.head()
# Out:
#   Case ID                                            PR_Link  \
# 0    PA-1   https://github.com/Altinn/altinn-broker/pull/259
# 1    PA-2  https://github.com/Hochfrequenz/kohlrahbi/pull...
# 2    PA-3  https://github.com/MartinsOnuoha/what-should-i...
# 3    PA-4   https://github.com/Opetushallitus/ludos/pull/102
# 4    PA-5  https://github.com/SharezoneApp/sharezone-app/...
#
#                                    Conversation_Link Outcome_Class  Context  \
# 0  https://chat.openai.com/share/b7853f70-84b8-47...            PA      1.0
# 1  https://chat.openai.com/share/4ad4c1ad-6f13-4a...            PA      1.0
# 2  https://chat.openai.com/share/2aa6268a-7a4e-47...            PA      2.0
# 3  https://chat.openai.com/share/bdfcb857-08a3-4f...            PA      1.0
# 4  https://chat.openai.com/share/fd82b66d-d949-43...            PA      2.0
#
#    Specificity  Verification  \
# 0          1.0           0.0
# 1          1.0           0.0
# 2          2.0           2.0
# 3          1.0           1.0
# 4          1.0           1.0
#
#                                            Rationale  PQS   PR_Size  ...  PQS  \
# 0  Context was scored 1 because the prompt provid...     2    125.0  ...    2
# 1  Context was scored 1 because the prompt provid...     2     51.0  ...    2
# 2  Context was scored 2 because the prompt mentio...     6    300.0  ...    6
# 3  Context was scored 1 because the prompt provid...     3    620.0  ...    3
# 4  Context was scored 2 because the prompt mentio...     4     18.0  ...    4
#
#                            Repository  PR_Number  Merged Closed  \
# 0                Altinn/altinn-broker        259       1      0
# 1              Hochfrequenz/kohlrahbi        158       1      0
# 2  MartinsOnuoha/what-should-i-design          8       1      0
# 3                Opetushallitus/ludos        102       1      0
# 4          SharezoneApp/sharezone-app        980       1      0
#
#    Generated_Code  Adopted_Code Resolved  Close_Event  Merge_Event
# 0               1             1        1            0            1
# 1               1             1        1            0            1
# 2               1             1        1            0            1
# 3               1             1        1            0            1
# 4               1             1        1            0            1
#
# [5 rows x 32 columns]

# %% [markdown]
# ## 2. Dataset shape and outcome-class counts
#
# These counts should align with the final downstream dataset used in the study.

# %%
print('Rows:', len(df))
print('Columns:', len(df.columns))
df['Outcome_Class'].value_counts().rename_axis('Outcome_Class').reset_index(name='count')
# Out:
# Rows: 273
# Columns: 32
#   Outcome_Class  count
# 0            PA     89
# 1            NE     84
# 2            PN     53
# 3            CL     47

# %% [markdown]
# ## 3. Prompt quality score distribution
#
# This section summarizes Context, Specificity, Verification, and PQS across the full dataset.

# %%
df[['Context','Specificity','Verification','PQS']].describe().round(3)
# Out:
#        Context  Specificity  Verification      PQS
# count  262.000      263.000       263.000  273.000
# mean     1.473        0.996         0.574    2.927
# std      0.623        0.602         0.567    1.466
# min      0.000        0.000         0.000    0.000
# 25%      1.000        1.000         0.000    2.000
# 50%      2.000        1.000         1.000    3.000
# 75%      2.000        1.000         1.000    4.000
# max      2.000        2.000         2.000    6.000

# %% [markdown]
# ## 4. PQS by outcome class
#
# This table supports the descriptive comparison across PA, PN, NE, and CL cases.

# %%
df.groupby('Outcome_Class')['PQS'].agg(['count','mean','median','std','min','max']).round(3)
# Out:
#                count   mean  median    std  min  max
# Outcome_Class
# CL                47  3.170     4.0  1.606    0    5
# NE                84  1.940     2.0  1.264    0    4
# PA                89  3.921     4.0  1.058    2    6
# PN                53  2.604     2.0  1.044    1    5

# %% [markdown]
# ## 5. Pull request size and language summaries
#
# These summaries motivate log-transforming PR size and controlling for project/task characteristics.

# %%
display(df['PR_Size'].describe().round(2))
df['PR_Language'].value_counts().head(15).rename_axis('language').reset_index(name='count')
# Out:
# count       269.00
# mean       1769.93
# std       11992.27
# min           0.00
# 25%          46.00
# 50%         202.00
# 75%         754.00
# max      182390.00
# Name: PR_Size, dtype: float64
#       language  count
# 0   TypeScript     67
# 1       Python     40
# 2     Markdown     30
# 3         YAML     22
# 4         JSON     15
# 5           Go     15
# 6          XML     11
# 7   JavaScript     11
# 8         Java      9
# 9          C++      9
# 10        Ruby      9
# 11        Rust      5
# 12       Other      4
# 13           C      4
# 14         PHP      3
